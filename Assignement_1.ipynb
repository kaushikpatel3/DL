# %%
import tensorflow as tf

# %%
print(tf.__version__)
# Out:
# 2.19.0

# %%
from tensorflow import keras

# %%
import torch

# %%
print(torch.__version__)
# Out:
# 2.7.1+cpu

# %%
import pandas as pd
import numpy as np
