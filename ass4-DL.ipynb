# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

from sklearn.preprocessing import StandardScaler
from sklearn.model_selection import train_test_split
from sklearn.metrics import classification_report, confusion_matrix, roc_auc_score

import tensorflow as tf
from tensorflow.keras import layers, models, regularizers

# %%
df=pd.read_csv("C:\\Users\\tejal\\Downloads\\creditcard.csv")
df.head()
# Out:
#    Time        V1        V2        V3        V4        V5        V6        V7  \
# 0   0.0 -1.359807 -0.072781  2.536347  1.378155 -0.338321  0.462388  0.239599
# 1   0.0  1.191857  0.266151  0.166480  0.448154  0.060018 -0.082361 -0.078803
# 2   1.0 -1.358354 -1.340163  1.773209  0.379780 -0.503198  1.800499  0.791461
# 3   1.0 -0.966272 -0.185226  1.792993 -0.863291 -0.010309  1.247203  0.237609
# 4   2.0 -1.158233  0.877737  1.548718  0.403034 -0.407193  0.095921  0.592941
#
#          V8        V9  ...       V21       V22       V23       V24       V25  \
# 0  0.098698  0.363787  ... -0.018307  0.277838 -0.110474  0.066928  0.128539
# 1  0.085102 -0.255425  ... -0.225775 -0.638672  0.101288 -0.339846  0.167170
# 2  0.247676 -1.514654  ...  0.247998  0.771679  0.909412 -0.689281 -0.327642
# 3  0.377436 -1.387024  ... -0.108300  0.005274 -0.190321 -1.175575  0.647376
# 4 -0.270533  0.817739  ... -0.009431  0.798278 -0.137458  0.141267 -0.206010
#
# ...

# %%
df['Class'].value_counts()#0=normal ,1=fraud
# Out:
# Class
# 0    284315
# 1       492
# Name: count, dtype: int64

# %%
df
# Out:
#             Time         V1         V2        V3        V4        V5  \
# 0            0.0  -1.359807  -0.072781  2.536347  1.378155 -0.338321
# 1            0.0   1.191857   0.266151  0.166480  0.448154  0.060018
# 2            1.0  -1.358354  -1.340163  1.773209  0.379780 -0.503198
# 3            1.0  -0.966272  -0.185226  1.792993 -0.863291 -0.010309
# 4            2.0  -1.158233   0.877737  1.548718  0.403034 -0.407193
# ...          ...        ...        ...       ...       ...       ...
# 284802  172786.0 -11.881118  10.071785 -9.834783 -2.066656 -5.364473
# 284803  172787.0  -0.732789  -0.055080  2.035030 -0.738589  0.868229
# 284804  172788.0   1.919565  -0.301254 -3.249640 -0.557828  2.630515
# 284805  172788.0  -0.240440   0.530483  0.702510  0.689799 -0.377961
# 284806  172792.0  -0.533413  -0.189733  0.703337 -0.506271 -0.012546
#
#               V6        V7        V8        V9  ...       V21       V22  \
# ...

# %%
X=df.drop(columns=['Class'])
Y=df['Class']

# %%
#scale time and amount
scaler=StandardScaler()
X[['Time','Amount']] = scaler.fit_transform(X[['Time','Amount']])
X[['Time','Amount']]
# Out:
#             Time    Amount
# 0      -1.996583  0.244964
# 1      -1.996583 -0.342475
# 2      -1.996562  1.160686
# 3      -1.996562  0.140534
# 4      -1.996541 -0.073403
# ...          ...       ...
# 284802  1.641931 -0.350151
# 284803  1.641952 -0.254117
# 284804  1.641974 -0.081839
# 284805  1.641974 -0.313249
# 284806  1.642058  0.514355
#
# [284807 rows x 2 columns]

# %%
X_train_all, X_test, Y_train_all, Y_test = train_test_split(
    X, Y, test_size=0.2, stratify=Y, random_state=42
)

# %%
X_train_all
# Out:
#             Time        V1        V2        V3        V4        V5        V6  \
# 265518  1.413095  1.946747 -0.752526 -1.355130 -0.661630  1.502822  4.024933
# 180305  0.624644  2.035149 -0.048880 -3.058693  0.247945  2.943487  3.298697
# 42664  -1.129186 -0.991920  0.603193  0.711976 -0.992425 -0.825838  1.956261
# 198723  0.796203  2.285718 -1.500239 -0.747565 -1.668119 -1.394143 -0.350339
# 82325  -0.746606 -0.448747 -1.011440  0.115903 -3.454854  0.715771 -0.147490
# ...          ...       ...       ...       ...       ...       ...       ...
# 233802  1.113883  1.993864 -0.516866 -0.620118  0.129845 -0.285128  0.395044
# 85418  -0.717019 -1.497933  0.657921  1.581568 -0.024286  0.584698  1.303031
# 29062  -1.253217  1.069777  0.072105  0.496540  1.505318 -0.380277 -0.370243
# 13766  -1.482496  1.280465  0.300586  0.333044  0.512720  0.065052 -0.145844
# 17677  -1.389125 -0.598120  0.775041  1.823394  0.312991 -0.096171 -0.391452
#
# ...

# %%
X_test
# Out:
#             Time        V1        V2        V3        V4        V5        V6  \
# 263020  1.388689 -0.674466  1.408105 -1.110622 -1.328366  1.388996 -1.308439
# 11378  -1.578646 -2.829816 -2.765149  2.537793 -1.074580  2.842559 -2.153536
# 147283 -0.136621 -3.576495  2.318422  1.306985  3.263665  1.127818  2.865246
# 219439  0.988041  2.060386 -0.015382 -1.082544  0.386019 -0.024331 -1.074935
# 36939  -1.180778  1.209965  1.384303 -1.343531  1.763636  0.662351 -2.113384
# ...          ...       ...       ...       ...       ...       ...       ...
# 54199  -1.020990 -0.863057  0.225429  2.458855  0.613099  0.067149  1.716173
# 184616  0.663243  1.397799 -1.426153 -0.369131  0.891825 -1.164153 -0.166657
# 274532  1.500506 -1.047727  0.685141  0.195457 -3.583402  0.082922 -0.444060
# 269819  1.452473  2.159972 -1.084234 -0.858819 -1.126188 -0.647032  0.234289
# 64170  -0.921365  1.228059 -0.603264  0.246723 -0.414322 -1.170914 -0.895176
#
# ...

# %%
Y_train_all
# Out:
# 265518    0
# 180305    0
# 42664     0
# 198723    0
# 82325     0
#          ..
# 233802    0
# 85418     0
# 29062     0
# 13766     0
# 17677     0
# Name: Class, Length: 227845, dtype: int64

# %%
Y_test
# Out:
# 263020    0
# 11378     0
# 147283    0
# 219439    0
# 36939     0
#          ..
# 54199     0
# 184616    0
# 274532    0
# 269819    0
# 64170     0
# Name: Class, Length: 56962, dtype: int64

# %%
X_train = X_train_all[Y_train_all==0]
X_train
# Out:
#             Time        V1        V2        V3        V4        V5        V6  \
# 265518  1.413095  1.946747 -0.752526 -1.355130 -0.661630  1.502822  4.024933
# 180305  0.624644  2.035149 -0.048880 -3.058693  0.247945  2.943487  3.298697
# 42664  -1.129186 -0.991920  0.603193  0.711976 -0.992425 -0.825838  1.956261
# 198723  0.796203  2.285718 -1.500239 -0.747565 -1.668119 -1.394143 -0.350339
# 82325  -0.746606 -0.448747 -1.011440  0.115903 -3.454854  0.715771 -0.147490
# ...          ...       ...       ...       ...       ...       ...       ...
# 233802  1.113883  1.993864 -0.516866 -0.620118  0.129845 -0.285128  0.395044
# 85418  -0.717019 -1.497933  0.657921  1.581568 -0.024286  0.584698  1.303031
# 29062  -1.253217  1.069777  0.072105  0.496540  1.505318 -0.380277 -0.370243
# 13766  -1.482496  1.280465  0.300586  0.333044  0.512720  0.065052 -0.145844
# 17677  -1.389125 -0.598120  0.775041  1.823394  0.312991 -0.096171 -0.391452
#
# ...

# %%
print("Train normals:", X_train.shape)
print("Test set:", X_test.shape)
# Out:
# Train normals: (227451, 30)
# Test set: (56962, 30)

# %%
input_dim=X_train.shape[1]
input_dim
# Out:
# 30

# %%
#build autoencoder
input_layer=layers.Input(shape=(input_dim,))
input_layer
# Out:
# <KerasTensor shape=(None, 30), dtype=float32, sparse=False, ragged=False, name=keras_tensor_8>

# %%
# Encoder
encoded = layers.Dense(32, activation="relu")(input_layer)
encoded = layers.Dense(16, activation="relu")(encoded)
bottleneck = layers.Dense(8, activation="relu", activity_regularizer=regularizers.l1(1e-5))(encoded)

# %%
# Decoder
decoded = layers.Dense(16, activation="relu")(bottleneck)
decoded = layers.Dense(32, activation="relu")(decoded)
output_layer = layers.Dense(input_dim, activation="linear")(decoded)

autoencoder = models.Model(inputs=input_layer, outputs=output_layer)

# %%
autoencoder.compile(optimizer='adam', loss='mse')
autoencoder.summary()
# Out:
# Model: "functional_1"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                         ┃ Output Shape                ┃         Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━┩
# │ input_layer_2 (InputLayer)           │ (None, 30)                  │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dense_6 (Dense)                      │ (None, 32)                  │             992 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dense_7 (Dense)                      │ (None, 16)                  │             528 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dense_8 (Dense)                      │ (None, 8)                   │             136 │
# ...

# %%
history=autoencoder.fit(X_train,X_train,epochs=20,batch_size=256,validation_split=0.1,shuffle=True,verbose=2)
# Out:
# Epoch 1/20
# 800/800 - 3s - 4ms/step - loss: 0.1210 - val_loss: 0.1207
# Epoch 2/20
# 800/800 - 3s - 4ms/step - loss: 0.1204 - val_loss: 0.1218
# Epoch 3/20
# 800/800 - 3s - 4ms/step - loss: 0.1207 - val_loss: 0.1197
# Epoch 4/20
# 800/800 - 3s - 4ms/step - loss: 0.1206 - val_loss: 0.1189
# Epoch 5/20
# 800/800 - 3s - 4ms/step - loss: 0.1201 - val_loss: 0.1197
# Epoch 6/20
# 800/800 - 3s - 4ms/step - loss: 0.1203 - val_loss: 0.1215
# Epoch 7/20
# 800/800 - 3s - 4ms/step - loss: 0.1202 - val_loss: 0.1219
# Epoch 8/20
# 800/800 - 3s - 4ms/step - loss: 0.1194 - val_loss: 0.1192
# Epoch 9/20
# 800/800 - 3s - 4ms/step - loss: 0.1201 - val_loss: 0.1214
# Epoch 10/20
# 800/800 - 3s - 4ms/step - loss: 0.1192 - val_loss: 0.1194
# Epoch 11/20
# 800/800 - 3s - 4ms/step - loss: 0.1202 - val_loss: 0.1197
# Epoch 12/20
# 800/800 - 3s - 4ms/step - loss: 0.1214 - val_loss: 0.1197
# Epoch 13/20
# 800/800 - 3s - 4ms/step - loss: 0.1190 - val_loss: 0.1188
# Epoch 14/20
# ...

# %%
# Plot training loss
plt.plot(history.history['loss'], label="train_loss")
plt.plot(history.history['val_loss'], label="val_loss")
plt.legend()
plt.title("Training Loss")
plt.show()

# %%
#evalute the model
# Predict on test set
X_test_pred = autoencoder.predict(X_test)
mse = np.mean(np.power(X_test - X_test_pred, 2), axis=1)
# Out:
# 1781/1781 ━━━━━━━━━━━━━━━━━━━━ 3s 2ms/step

# %%
# Pick threshold (here simple: mean + 3*std on training errors)
X_train_pred = autoencoder.predict(X_train)
train_mse = np.mean(np.power(X_train - X_train_pred, 2), axis=1)
threshold = train_mse.mean() + 3*train_mse.std()
# Out:
# 7108/7108 ━━━━━━━━━━━━━━━━━━━━ 13s 2ms/step

# %%
print("Threshold:", threshold)
# Out:
# Threshold: 0.7355348138275729

# %%
# Predictions
y_pred = (mse > threshold).astype(int)
y_pred
# Out:
# 263020    0
# 11378     0
# 147283    0
# 219439    0
# 36939     0
#          ..
# 54199     0
# 184616    0
# 274532    0
# 269819    0
# 64170     0
# Length: 56962, dtype: int64

# %%
# Evaluation
print("Confusion Matrix:\n", confusion_matrix(Y_test, y_pred))
print("\nClassification Report:\n", classification_report(Y_test, y_pred))
print("ROC AUC:", roc_auc_score(Y_test, mse))
# Out:
# Confusion Matrix:
#  [[56081   783]
#  [   25    73]]
#
# Classification Report:
#                precision    recall  f1-score   support
#
#            0       1.00      0.99      0.99     56864
#            1       0.09      0.74      0.15        98
#
#     accuracy                           0.99     56962
#    macro avg       0.54      0.87      0.57     56962
# weighted avg       1.00      0.99      0.99     56962
#
# ROC AUC: 0.9472902765495619

# %%
# Plot distribution of reconstruction errors
plt.figure(figsize=(8,5))
sns.histplot(mse[Y_test==0], label="Normal", color="green", kde=True, stat="density")
sns.histplot(mse[Y_test==1], label="Fraud", color="red", kde=True, stat="density")
plt.axvline(threshold, color="black", linestyle="--", label="Threshold")
plt.legend()
plt.title("Reconstruction Error Distribution")
plt.show()
